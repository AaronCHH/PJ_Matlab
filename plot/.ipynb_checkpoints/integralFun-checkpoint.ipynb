% %%
f = inline('exp(-x).*quadv(@(y) sin(y^2), 0, x)', 'x')
% Out:
% f =
%
%      Inline function:
%      f(x) = exp(-x).*quadv(@(y) sin(y^2), 0, x)

% %%
x = 0:0.01:10;
for i = 1:length(x)
    y(i) = f(x(i));
end

plot(x, y)
title('Graph of exp(-x^2)\int_0^x sin(y^2) dy')
