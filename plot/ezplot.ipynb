% %%
% inline function
f = inline('a*x^2 + b*x + c', 'a', 'b', 'c', 'x');

% %%
ezplot(@(x) f(1,-2,3,x))
% Out:
% ...
% > In ezplot>ezplot1 (line 488)
%   In ezplot (line 144)

% %%
ezplot(@(a) f(a,-2,3,4))

% %%
ezplot(@(x) f(1,-2,3,x), [-6*pi 6*pi])
% Out:
% ...
% > In ezplot>ezplot1 (line 488)
%   In ezplot (line 144)
